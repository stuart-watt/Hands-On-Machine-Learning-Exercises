# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pkt

# %%
pd.set_option('display.max_columns', None)

names = ['name', 'landmass', 'zone', 'area', 'population', 'language',
         'religion', 'bars', 'stripes', 'colours', 'red', 'green',
         'blue', 'gold', 'white', 'black', 'orange', 'mainhue', 'circles',
         'crosses', 'saltires', 'quarters', 'sunstars', 'cresent', 'triangle',
         'icon', 'animate', 'text', 'topleft', 'botright']
data = pd.read_csv('flag_data.csv', names=names)
data.head(15)
# Out:
#                name  landmass  zone  area  population  language  religion  \
# 0       Afghanistan         5     1   648          16        10         2
# 1           Albania         3     1    29           3         6         6
# 2           Algeria         4     1  2388          20         8         2
# 3    American-Samoa         6     3     0           0         1         1
# 4           Andorra         3     1     0           0         6         0
# 5            Angola         4     2  1247           7        10         5
# 6          Anguilla         1     4     0           0         1         1
# 7   Antigua-Barbuda         1     4     0           0         1         1
# 8         Argentina         2     3  2777          28         2         0
# 9         Argentine         2     3  2777          28         2         0
# 10        Australia         6     2  7690          15         1         1
# 11          Austria         3     1    84           8         4         0
# ...

# %%
countries = data['name']

# I will split the colour information into 3 categories: The first decides how many colours,
# the second decides which colours based on the first decision. The last sets the coluor hierarchy.
colours1 = data[['colours']]
colours2 = data[['red', 'green', 'blue', 'gold', 'white', 'black', 'orange']]
colours3 = data[['mainhue', 'topleft', 'botright']]

# The design of the flag comes next. 
# The flag will be split into 4 quarters. 0 means no splitting (eg Japan, Canada, etc), 
# 1 will assume top left (eg, Australia, Greece etc) and 4 will be four quarters (only applies to Panama)
# The bars, stripes, crosses and saltiers will be chosen to be independent. 
# This will be chosen for each quarter as defined in shapes1

shapes1 = data[['quarters']]
shapes2 = data[['bars', 'stripes', 'circles', 'crosses', 'saltires', 'quarters', 'sunstars',
              'cresent', 'triangle','icon', 'animate']]

# These are the features the model will work off. These are the inputs that the user will give
# Later versions of the flag generator may allow landmass and zone to be selected off a map.
features = data[['landmass', 'zone', 'area', 'population', 'language', 'religion']]
